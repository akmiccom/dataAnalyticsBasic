# %%
from glob import glob
import pandas as pd

# %%
files = glob("../csv/例題_データアナリティクス基礎/*")
# for i, f in enumerate(files):
#     print(i, f)

# %%
purchase_data = pd.read_excel(files[3])
purchase_data.columns = ['id', 'customer_id', 'price', 'food', 'weekday', 'gender']
purchase_data.head()
# Out:
#    id  customer_id  price  food weekday gender
# 0   1          153    220     肉     火曜日     女性
# 1   2          263    760  魚貝缶詰     火曜日     女性
# 2   3          321    920     卵     火曜日     男性
# 3   4          349    700    軽食     火曜日     女性
# 4   5          402    950    パン     火曜日     女性

# %% [markdown]
# パレート表

# %%
item_count = purchase_data.pivot_table(index='food', values='customer_id', aggfunc='count')
item_count.rename(columns={'customer_id': 'count'}, inplace=True)
item_count = item_count.sort_values(by='count', ascending=False)
item_count['cumsum'] = item_count.cumsum()
item_count['ratio'] = item_count['count'] / item_count['count'].sum()
item_count['c_ratio'] = item_count['cumsum'] / item_count['count'].sum()
item_count
# Out:
#        count  cumsum     ratio   c_ratio
# food
# 野菜       683     683  0.187175  0.187175
# 軽食       612    1295  0.167717  0.354892
# 菓子類      491    1786  0.134557  0.489449
# 乳製品      268    2054  0.073445  0.562894
# 肉        267    2321  0.073171  0.636065
# 果物       241    2562  0.066045  0.702110
# パン       227    2789  0.062209  0.764319
# 朝食用食品    150    2939  0.041107  0.805426
# 調理用品     143    3082  0.039189  0.844615
# 缶スープ     143    3225  0.039189  0.883804
# 米・麺類      95    3320  0.026035  0.909838
# 卵         88    3408  0.024116  0.933955
# 魚貝缶詰      83    3491  0.022746  0.956700
# おかず       49    3540  0.013428  0.970129
# 冷凍食品      49    3589  0.013428  0.983557
# 海鮮品       35    3624  0.009592  0.993149
# ツナ缶       25    3649  0.006851  1.000000

# %%
item_price = purchase_data.pivot_table(index='food', values='price', aggfunc='sum')
item_price = item_price.sort_values(by='price', ascending=False)
item_price['cumsum'] = item_price.cumsum()
item_price['ratio'] = item_price['price'] / item_price['price'].sum()
item_price['c_ratio'] = item_price['cumsum'] / item_price['price'].sum()
item_price
# Out:
#         price   cumsum     ratio   c_ratio
# food
# 野菜     542650   542650  0.189181  0.189181
# 軽食     492730  1035380  0.171777  0.360958
# 菓子類    357130  1392510  0.124504  0.485462
# 乳製品    234310  1626820  0.081686  0.567148
# 肉      216600  1843420  0.075512  0.642660
# 果物     185400  2028820  0.064635  0.707295
# パン     179220  2208040  0.062480  0.769776
# 朝食用食品  110730  2318770  0.038603  0.808379
# 缶スープ   104820  2423590  0.036543  0.844922
# 調理用品    94520  2518110  0.032952  0.877874
# 米・麺類    83610  2601720  0.029148  0.907022
# 魚貝缶詰    75190  2676910  0.026213  0.933235
# 卵       71530  2748440  0.024937  0.958172
# 冷凍食品    40540  2788980  0.014133  0.972305
# おかず     33150  2822130  0.011557  0.983862
# 海鮮品     28810  2850940  0.010044  0.993906
# ツナ缶     17480  2868420  0.006094  1.000000

# %% [markdown]
# 食品の種類の数

# %%
print(item_count.shape[0])
# Out:
# 17

# %% [markdown]
# 購入された数

# %%
item_count
# Out:
#        count  cumsum     ratio   c_ratio
# food
# 野菜       683     683  0.187175  0.187175
# 軽食       612    1295  0.167717  0.354892
# 菓子類      491    1786  0.134557  0.489449
# 乳製品      268    2054  0.073445  0.562894
# 肉        267    2321  0.073171  0.636065
# 果物       241    2562  0.066045  0.702110
# パン       227    2789  0.062209  0.764319
# 朝食用食品    150    2939  0.041107  0.805426
# 調理用品     143    3082  0.039189  0.844615
# 缶スープ     143    3225  0.039189  0.883804
# 米・麺類      95    3320  0.026035  0.909838
# 卵         88    3408  0.024116  0.933955
# 魚貝缶詰      83    3491  0.022746  0.956700
# おかず       49    3540  0.013428  0.970129
# 冷凍食品      49    3589  0.013428  0.983557
# 海鮮品       35    3624  0.009592  0.993149
# ツナ缶       25    3649  0.006851  1.000000

# %% [markdown]
# 購入金額上位3位までの割合

# %%
print(f"{item_price['c_ratio'][2]:.03f}")
# Out:
# 0.485

# %% [markdown]
# 軽食の曜日別比較

# %%
food_weekday_sum = purchase_data.pivot_table(index='food', columns='weekday', values='price', aggfunc='sum').fillna(0)
food_weekday_sum
# Out:
# weekday      土曜日       日曜日      月曜日      木曜日      水曜日      火曜日      金曜日
# food
# おかず       2140.0    9210.0   6970.0   7480.0   3200.0   2270.0   1880.0
# ツナ缶        310.0    7080.0   1600.0   4850.0      0.0   2430.0   1210.0
# パン        7770.0   78410.0  13910.0  27140.0  25000.0  16700.0  10290.0
# 乳製品      14630.0   91460.0  24520.0  31590.0  30540.0  25780.0  15790.0
# 冷凍食品       880.0   22090.0   3390.0   3220.0   4350.0   4030.0   2580.0
# 卵         1800.0   31740.0  10460.0   7090.0   9960.0   7300.0   3180.0
# 朝食用食品     1610.0   43400.0  18490.0  16570.0  11510.0   8340.0  10810.0
# 果物        9590.0   64790.0  30640.0  20540.0  29010.0  14490.0  16340.0
# 海鮮品       1250.0   13900.0   3600.0   2740.0   4070.0   2640.0    610.0
# 米・麺類      4600.0   36480.0   6090.0  18230.0   7780.0   5780.0   4650.0
# 缶スープ      4800.0   44090.0  12390.0  13200.0  14340.0   8900.0   7100.0
# 肉         6680.0   88610.0  37630.0  19200.0  28820.0  19440.0  16220.0
# 菓子類      16240.0  138920.0  34350.0  49100.0  48850.0  37510.0  32160.0
# 調理用品      7740.0   41110.0  10240.0  12750.0   7960.0   9490.0   5230.0
# 軽食       30950.0  194130.0  69050.0  48530.0  60190.0  56800.0  33080.0
# 野菜       27200.0  225850.0  65210.0  84690.0  65910.0  39100.0  34690.0
# 魚貝缶詰      3670.0   28570.0  12830.0  11010.0   9650.0   7790.0   1670.0

# %%
food_weekday_sum.loc['軽食']
# Out:
# weekday
# 土曜日     30950.0
# 日曜日    194130.0
# 月曜日     69050.0
# 木曜日     48530.0
# 水曜日     60190.0
# 火曜日     56800.0
# 金曜日     33080.0
# Name: 軽食, dtype: float64

# %% [markdown]
# 特化係数

# %%
food_weekday_ratio = purchase_data.pivot_table(index='food', columns='weekday', values='customer_id', aggfunc='count').fillna(0)
# food_weekday_ratio['総計'] = [food_weekday_ratio.loc[index].sum() for index in food_weekday_ratio.index]
food_weekday_ratio = food_weekday_ratio.apply(lambda x: x /sum(x), axis=0)
food_weekday_ratio
# Out:
# weekday       土曜日       日曜日       月曜日       木曜日       水曜日       火曜日       金曜日
# food
# おかず      0.022222  0.009440  0.019523  0.019780  0.010823  0.013928  0.012048
# ツナ缶      0.005556  0.006743  0.004338  0.013187  0.000000  0.011142  0.008032
# パン       0.055556  0.063385  0.045553  0.065934  0.071429  0.069638  0.056225
# 乳製品      0.088889  0.071477  0.073753  0.076923  0.073593  0.075209  0.064257
# 冷凍食品     0.005556  0.016858  0.008677  0.006593  0.012987  0.016713  0.016064
# 卵        0.022222  0.026298  0.026030  0.019780  0.025974  0.022284  0.016064
# 朝食用食品    0.022222  0.038436  0.056399  0.046154  0.045455  0.025070  0.048193
# 果物       0.061111  0.056642  0.082430  0.063736  0.073593  0.069638  0.080321
# 海鮮品      0.011111  0.012138  0.010846  0.006593  0.008658  0.005571  0.004016
# 米・麺類     0.027778  0.027647  0.015184  0.041758  0.019481  0.025070  0.020080
# 缶スープ     0.033333  0.041133  0.030369  0.032967  0.041126  0.044568  0.048193
# 肉        0.050000  0.076871  0.095445  0.048352  0.082251  0.064067  0.068273
# 菓子類      0.133333  0.132839  0.106291  0.138462  0.136364  0.142061  0.176707
# 調理用品     0.050000  0.039110  0.036876  0.037363  0.028139  0.050139  0.044177
# 軽食       0.194444  0.165880  0.182213  0.138462  0.166667  0.192201  0.152610
# 野菜       0.188889  0.194875  0.177874  0.215385  0.179654  0.150418  0.172691
# 魚貝缶詰     0.027778  0.020229  0.028200  0.028571  0.023810  0.022284  0.012048
